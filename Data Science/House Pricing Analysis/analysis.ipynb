# %% [markdown]
# ### Import Libraries

# %%
# For data manipulation
import pandas as pd 
from datetime import datetime as dt

# For data visualization
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Pre-processing

# %%
df = pd.read_csv('./home_data.csv')
df.head()
# Out:
#               date      price  bedrooms  bathrooms  sqft_living  sqft_lot
# 0  20140924T000000  5298269.0       5.0       4.00       5342.0   40607.0  \
# 1  20150327T000000   724794.0       4.0       2.50       2397.0    8699.0
# 2  20140818T000000   260531.0       3.0       1.75       1306.0    8121.0
# 3  20140912T000000   460328.0       2.0       2.00       1343.0    1133.0
# 4  20140917T000000   662285.0       3.0       3.25       2240.0  744643.0
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement
# 0     2.0         0.0   3.0        4.0    9.0      4251.0         1301.0  \
# 1     2.0         0.0   0.0        4.0    8.0      2672.0            0.0
# 2     1.0         0.0   0.0        3.0    7.0      1306.0            0.0
# 3     2.0         0.0   0.0        3.0    8.0      1122.0          211.0
# 4     1.5         0.0   2.0        3.0    7.0      1658.0          824.0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           59633 non-null  object
#  1   price          59633 non-null  float64
#  2   bedrooms       59633 non-null  float64
#  3   bathrooms      59633 non-null  float64
#  4   sqft_living    59633 non-null  float64
#  5   sqft_lot       59633 non-null  float64
#  6   floors         59633 non-null  float64
#  7   waterfront     59633 non-null  float64
#  8   view           59633 non-null  float64
#  9   condition      59633 non-null  float64
#  10  grade          59633 non-null  float64
#  11  sqft_above     59633 non-null  float64
#  12  sqft_basement  59633 non-null  float64
#  13  yr_built       59633 non-null  float64
#  14  yr_renovated   59633 non-null  float64
#  15  zipcode        59633 non-null  float64
#  16  lat            59633 non-null  float64
# ...

# %%
df.describe()
# Out:
#               price     bedrooms     bathrooms   sqft_living       sqft_lot
# count  5.963300e+04  59633.00000  59633.000000  59633.000000   59633.000000  \
# mean   5.526489e+05      3.36297      2.116693   2118.135495   18141.024114
# std    4.388506e+05      0.89857      0.779162    997.365833   65233.612553
# min    8.250100e+04      0.00000      0.000000    390.000000     639.000000
# 25%    3.205590e+05      3.00000      1.500000   1432.000000    5122.000000
# 50%    4.510220e+05      3.00000      2.250000   1941.000000    7682.000000
# 75%    6.453930e+05      4.00000      2.500000   2598.000000   10814.000000
# max    5.299041e+06      9.00000      6.000000   9189.000000  981955.000000
#
#              floors    waterfront          view     condition         grade
# count  59633.000000  59633.000000  59633.000000  59633.000000  59633.000000  \
# mean       1.492261      0.004997      0.235658      3.421260      7.683313
# ...

# %%
df.isnull().sum()
# Out:
# date             367
# price            367
# bedrooms         367
# bathrooms        367
# sqft_living      367
# sqft_lot         367
# floors           367
# waterfront       367
# view             367
# condition        367
# grade            367
# sqft_above       367
# sqft_basement    367
# yr_built         367
# yr_renovated     367
# zipcode          367
# lat              367
# long             367
# sqft_living15    367
# sqft_lot15       367
# Age of House     367
# dtype: int64

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
### change date format

df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#         date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors
# 0 2014-09-24  5298269.0       5.0       4.00       5342.0   40607.0     2.0  \
# 1 2015-03-27   724794.0       4.0       2.50       2397.0    8699.0     2.0
# 2 2014-08-18   260531.0       3.0       1.75       1306.0    8121.0     1.0
# 3 2014-09-12   460328.0       2.0       2.00       1343.0    1133.0     2.0
# 4 2014-09-17   662285.0       3.0       3.25       2240.0  744643.0     1.5
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built
# 0         0.0   3.0        4.0    9.0      4251.0         1301.0    1968.0  \
# 1         0.0   0.0        4.0    8.0      2672.0            0.0    1989.0
# 2         0.0   0.0        3.0    7.0      1306.0            0.0    1955.0
# 3         0.0   0.0        3.0    8.0      1122.0          211.0    2006.0
# 4         0.0   2.0        3.0    7.0      1658.0          824.0    2000.0
#
# ...

# %%
current_year = dt.now().year
df['Age of House'] =  current_year - df['date'].dt.year
df.head(3)
# Out:
#         date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors
# 0 2014-09-24  5298269.0       5.0       4.00       5342.0   40607.0     2.0  \
# 1 2015-03-27   724794.0       4.0       2.50       2397.0    8699.0     2.0
# 2 2014-08-18   260531.0       3.0       1.75       1306.0    8121.0     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built
# 0         0.0   3.0        4.0  ...      4251.0         1301.0    1968.0  \
# 1         0.0   0.0        4.0  ...      2672.0            0.0    1989.0
# 2         0.0   0.0        3.0  ...      1306.0            0.0    1955.0
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0           0.0  98004.0  47.6192 -122.209         3564.0     14274.0  \
# 1           0.0  98033.0  47.6959 -122.192         1936.0      7863.0
# 2           0.0  98168.0  47.4747 -122.332         1249.0      8103.0
#
#    Age of House
# 0           9.0
# 1           8.0
# 2           9.0
#
# ...

# %%
df.interpolate(method='linear', inplace=True)

# %%
columns_to_convert = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
                       'floors', 'waterfront', 'view', 'condition', 'grade',
                       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
                       'zipcode', 'sqft_living15', 'sqft_lot15', 'Age of House']

for column in columns_to_convert:
    df[column] = df[column].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           60000 non-null  datetime64[ns]
#  1   price          60000 non-null  int64
#  2   bedrooms       60000 non-null  int64
#  3   bathrooms      60000 non-null  int64
#  4   sqft_living    60000 non-null  int64
#  5   sqft_lot       60000 non-null  int64
#  6   floors         60000 non-null  int64
#  7   waterfront     60000 non-null  int64
#  8   view           60000 non-null  int64
#  9   condition      60000 non-null  int64
#  10  grade          60000 non-null  int64
#  11  sqft_above     60000 non-null  int64
#  12  sqft_basement  60000 non-null  int64
#  13  yr_built       60000 non-null  int64
#  14  yr_renovated   60000 non-null  int64
#  15  zipcode        60000 non-null  int64
#  16  lat            60000 non-null  float64
# ...

# %% [markdown]
# ### EDA

# %%
columns_of_interest = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
                       'floors', 'waterfront', 'view', 'condition', 'grade',
                       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
                       'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

correlation_matrix = df[columns_of_interest].corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
